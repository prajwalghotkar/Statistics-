# %% [markdown]
# ### Parametric Density Estimation

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

sample = normal(loc=50, scale=5,size=1000)

# %%
sample.mean()
# Out:
# 49.581902947160025

# %% [markdown]
# #### plot histogram to understand the distribution of data

# %%
plt.hist(sample,bins=10)
# Out:
# (array([  5.,  24.,  93., 169., 247., 231., 150.,  64.,  14.,   3.]),
#  array([33.81527868, 37.06564973, 40.31602077, 43.56639181, 46.81676285,
#         50.0671339 , 53.31750494, 56.56787598, 59.81824702, 63.06861807,
#         66.31898911]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### calculate sample mean and sample std dev

# %%
sample_mean = sample.mean()
sample_std = sample.std()

# %%
sample_mean
# Out:
# 49.581902947160025

# %%
sample_std
# Out:
# 4.965408805655457

# %% [markdown]
# #### fit the distribution with the above parameters

# %%
from scipy.stats import norm
dist = norm(sample_mean, sample_std)
dist

# %%
sample.min()
# Out:
# 33.8152786831493

# %%
sample.max()
# Out:
# 66.3189891099195

# %%
values = np.linspace(sample.min(),sample.max(),100)
values
# Out:
# array([33.81527868, 34.14359899, 34.4719193 , 34.80023961, 35.12855991,
#        35.45688022, 35.78520053, 36.11352083, 36.44184114, 36.77016145,
#        37.09848176, 37.42680206, 37.75512237, 38.08344268, 38.41176299,
#        38.74008329, 39.0684036 , 39.39672391, 39.72504422, 40.05336452,
#        40.38168483, 40.71000514, 41.03832544, 41.36664575, 41.69496606,
#        42.02328637, 42.35160667, 42.67992698, 43.00824729, 43.3365676 ,
#        43.6648879 , 43.99320821, 44.32152852, 44.64984883, 44.97816913,
#        45.30648944, 45.63480975, 45.96313005, 46.29145036, 46.61977067,
#        46.94809098, 47.27641128, 47.60473159, 47.9330519 , 48.26137221,
#        48.58969251, 48.91801282, 49.24633313, 49.57465344, 49.90297374,
#        50.23129405, 50.55961436, 50.88793466, 51.21625497, 51.54457528,
#        51.87289559, 52.20121589, 52.5295362 , 52.85785651, 53.18617682,
#        53.51449712, 53.84281743, 54.17113774, 54.49945805, 54.82777835,
#        55.15609866, 55.48441897, 55.81273928, 56.14105958, 56.46937989,
#        56.7977002 , 57.1260205 , 57.45434081, 57.78266112, 58.11098143,
#        58.43930173, 58.76762204, 59.09594235, 59.42426266, 59.75258296,
#        60.08090327, 60.40922358, 60.73754389, 61.06586419, 61.3941845 ,
#        61.72250481, 62.05082511, 62.37914542, 62.70746573, 63.03578604,
#        63.36410634, 63.69242665, 64.02074696, 64.34906727, 64.67738757,
#        65.00570788, 65.33402819, 65.6623485 , 65.9906688 , 66.31898911])

# %%
probabilities = [dist.pdf(value) for value in values]

# %%
probabilities
# Out:
# [0.0005194839167563716,
#  0.0006394477616629755,
#  0.0007836809283882352,
#  0.0009562572165513336,
#  0.0011617466120518488,
#  0.0014052362513562013,
#  0.001692343495145184,
#  0.002029219043043431,
#  0.0024225379175963377,
#  0.0028794761036016908,
#  0.0034076706628314436,
#  0.004015161267908067,
#  0.004710311324913487,
#  0.00550170719201796,
#  0.00639803445737554,
#  0.007407930815674814,
#  0.008539815775665576,
#  0.009801698231235539,
#  0.011200963820098225,
#  0.012744144953899401,
#  0.01443667740178345,
#  0.01628264831008667,
#  0.018284541502314358,
#  0.020442986780308436,
#  0.022756520691568746,
#  0.025221366790898373,
#  0.02783124376094404,
#  0.030577209824636686,
#  0.033447551649317786,
#  0.03642772538377078,
#  0.03950035657409797,
#  0.042645304475195614,
#  0.045839794729744913,
#  0.04905862256046959,
#  0.052274426563987085,
#  0.05545803097065571,
#  0.0585788519217835,
#  0.061605361000581275,
#  0.06450559702968595,
#  0.06724771511129664,
#  0.06980056012876751,
#  0.07213425053641384,
#  0.07422075731101165,
#  0.0760344624816614,
#  0.07755268173247191,
#  0.07875613620081158,
#  0.0796293597648573,
#  0.080161029795906,
#  0.08034421148825849,
#  0.08017650839624045,
#  0.07966011461011882,
#  0.07880176698284434,
#  0.07761259886177964,
#  0.07610789976497415,
#  0.07430678825394912,
#  0.0722318077864154,
#  0.06990845748819922,
#  0.06736467148683435,
#  0.06463026164366567,
#  0.061736339173911234,
#  0.0587147307460587,
#  0.055597404218122835,
#  0.05241591823585344,
#  0.049200908543822676,
#  0.04598162211750986,
#  0.04278550819814659,
#  0.0396378730947615,
#  0.036561603304922,
#  0.033576959190645274,
#  0.030701439216374467,
#  0.027949712689674513,
#  0.02533361710774743,
#  0.02286221465477132,
#  0.020541901151432593,
#  0.018376559847830813,
#  0.01636775187764005,
#  0.014514934944240068,
#  0.012815701865291086,
#  0.011266030927615592,
#  0.009860540558385375,
#  0.008592741555692387,
#  0.0074552809934923464,
#  0.006440172874645616,
#  0.005539011605588093,
#  0.0047431653653100874,
#  0.004043947403444998,
#  0.003432764197305797,
#  0.0029012402023798345,
#  0.002441319628710921,
#  0.002045346257010598,
#  0.00170612276960285,
#  0.0014169514141328025,
#  0.001171658048539521,
#  0.0009646017437860459,
#  0.0007906721584497555,
#  0.0006452768602699891,
#  0.0005243206686032151,
#  0.000424178942882762,
#  0.0003416665593942317,
#  0.00027400411459267297]

# %% [markdown]
# #### plot the histogram and pdf

# %%
plt.hist(sample,bins=10,density=True)
plt.plot(values,probabilities)

# %%
import seaborn as sns
sns.distplot(sample)
# Out:
# C:\Users\pmgho\AppData\Local\Temp\ipykernel_22256\1482356190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>

# %%
from scipy.stats import norm
dist = norm(60, 12)

# %%
values = np.linspace(sample.min(),sample.max(),100)
values
# Out:
# array([33.81527868, 34.14359899, 34.4719193 , 34.80023961, 35.12855991,
#        35.45688022, 35.78520053, 36.11352083, 36.44184114, 36.77016145,
#        37.09848176, 37.42680206, 37.75512237, 38.08344268, 38.41176299,
#        38.74008329, 39.0684036 , 39.39672391, 39.72504422, 40.05336452,
#        40.38168483, 40.71000514, 41.03832544, 41.36664575, 41.69496606,
#        42.02328637, 42.35160667, 42.67992698, 43.00824729, 43.3365676 ,
#        43.6648879 , 43.99320821, 44.32152852, 44.64984883, 44.97816913,
#        45.30648944, 45.63480975, 45.96313005, 46.29145036, 46.61977067,
#        46.94809098, 47.27641128, 47.60473159, 47.9330519 , 48.26137221,
#        48.58969251, 48.91801282, 49.24633313, 49.57465344, 49.90297374,
#        50.23129405, 50.55961436, 50.88793466, 51.21625497, 51.54457528,
#        51.87289559, 52.20121589, 52.5295362 , 52.85785651, 53.18617682,
#        53.51449712, 53.84281743, 54.17113774, 54.49945805, 54.82777835,
#        55.15609866, 55.48441897, 55.81273928, 56.14105958, 56.46937989,
#        56.7977002 , 57.1260205 , 57.45434081, 57.78266112, 58.11098143,
#        58.43930173, 58.76762204, 59.09594235, 59.42426266, 59.75258296,
#        60.08090327, 60.40922358, 60.73754389, 61.06586419, 61.3941845 ,
#        61.72250481, 62.05082511, 62.37914542, 62.70746573, 63.03578604,
#        63.36410634, 63.69242665, 64.02074696, 64.34906727, 64.67738757,
#        65.00570788, 65.33402819, 65.6623485 , 65.9906688 , 66.31898911])

# %%
probabilities = [dist.pdf(value) for value in values]

# %%
plt.hist(sample,bins=10,density=True)
plt.plot(values,probabilities)

# %%
import seaborn as sns
sns.distplot(sample)
# Out:
# C:\Users\pmgho\AppData\Local\Temp\ipykernel_22256\1482356190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>
